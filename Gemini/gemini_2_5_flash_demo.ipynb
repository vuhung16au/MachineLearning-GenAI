# %% [markdown]
# # Overview
#
# Demonstrate how to use `gemini-2.5-flash` with various input: text, audio, document files.

# %% [markdown]
# # Install Required Libraries

# %%
# %pip install -q -U google-genai pillow pypdf moviepy ffmpeg
# Out:
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Users/vuhung/Desktop/MachineLearning-GenAI/Gemini/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Define the Model

# %%
model="gemini-2.5-flash"

# %% [markdown]
# # Setup Environment

# %%
from google import genai
import os
from pathlib import Path
# Try to import userdata for Colab detection
try:
    from google.colab import userdata
    COLAB_AVAILABLE = True
except ImportError:
    COLAB_AVAILABLE = False
def load_env_file(env_path):
    """Load environment variables from .env file"""
    env_vars = {}
    if os.path.exists(env_path):
        with open(env_path, 'r') as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith('#') and '=' in line:
                    key, value = line.split('=', 1)
                    env_vars[key.strip()] = value.strip().strip('"').strip("'")
    return env_vars
GOOGLE_API_KEY = None
if COLAB_AVAILABLE:
    try:
        # Check if running on Colab
        GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
        print("Running on Google Colab, using GOOGLE_API_KEY secret.")
    except:
        print("Running on Google Colab, but GOOGLE_API_KEY secret not found.")
else:
    # Running locally - try to load from .env.local file
    env_file_path = Path.home() / "Documents" / "LangGraph-Credentials" / ".env.local"
    if env_file_path.exists():
        print(f"Running locally, reading API key from {env_file_path}.")
        env_vars = load_env_file(env_file_path)
        GOOGLE_API_KEY = env_vars.get('GOOGLE_API_KEY')
        if not GOOGLE_API_KEY:
            print("GOOGLE_API_KEY not found in .env.local file.")
    else:
        print(f"Running locally, but .env.local file not found at {env_file_path}.")
        print("Please create the file with: GOOGLE_API_KEY=your_api_key_here")
if GOOGLE_API_KEY:
    print("Gemini API key configured successfully.")
else:
    print("Gemini API key not found. Please provide the API key.")
# Out:
# Running locally, reading API key from /Users/vuhung/Documents/LangGraph-Credentials/.env.local.
# Gemini API key configured successfully.

# %% [markdown]
# # Generate Text Answers

# %%
# Select a Gemini model that supports text input
client = genai.Client(api_key=GOOGLE_API_KEY)
# Define a string variable containing the text you want to use as input
text_input = "Tell me a short story about a Blue Mountain (Sydney)"
# Use the selected Gemini model to generate content based on the text input
response = client.models.generate_content(
        model=model,
        contents=text_input
)
print(response.text)
# Out:
# Elara felt the city tension unravel with every kilometer her little car climbed, the eucalyptus scent growing stronger, fresher. Sydney, with its glittering harbour and urban hum, felt a world away, even though it was only a few hours behind her. She was heading for the Blue Mountains, for a breath of that famed, mist-kissed air.
#
# She pulled into a lookout point, not the bustling Echo Point, but a quieter ledge overlooking the vast expanse of the Grose Valley. Below her, a sea of gum trees stretched to the horizon, not green, but a mesmerizing, undeniable blue. The tiny oil droplets evaporating from the eucalyptus leaves, scattering the light, painted the entire landscape in a melancholic, ethereal sapphire.
#
# A kookaburra’s laugh echoed through the valley, a joyful, raucous sound that somehow only deepened the profound silence. Elara leant against the sandstone railing, her hands cool on the ancient rock. She watched a hawk circle lazily on an updraft, a tiny speck against the immense sky. The scale of it all was humbling. Her city worries, her deadlines, her petty grievances, seemed to shrink to nothing in the face of such ancient, enduring beauty.
#
# As the late afternoon sun began to dip, painting the cliff faces in warm oranges and purples before the blue haze reclaimed them, Elara felt a deep calm settle over her. The Blue Mountains hadn't just offered a view; they offered a perspective. And as she finally turned her car back towards the distant, faint glow of Sydney, she carried a piece of that quiet, blue magic with her.

# %% [markdown]
# # Image File Processing Demo

# %% [markdown]
# ## Load Image File & Describe

# %%
import requests
from PIL import Image
# Download an image from a URL
image_url = "https://raw.githubusercontent.com/vuhung16au/MachineLearning-GenAI/refs/heads/main/Gemini/phongnha.png"
image_path = "phongnha.png"
try:
    # Download the image
    response = requests.get(image_url)
    response.raise_for_status()  # Raise an exception for bad status codes
    with open(image_path, 'wb') as f:
        f.write(response.content)
    print(f"Image downloaded successfully to {image_path}")
    # Load the image
    img = Image.open(image_path)
    print("Image loaded successfully.")
except requests.exceptions.RequestException as e:
    print(f"Error downloading image: {e}")
    img = None
except FileNotFoundError:
    print(f"Error: Image file not found at {image_path}")
    img = None
if img:
    # Define a prompt
    prompt = "Describe this image."
    # Select a Gemini model that supports multimodal input
    # Make sure to use a model that supports both text and image input.
    # The list of available models can be checked with `genai.list_models()`.
    # The configured model supports multimodal input.
    client = genai.Client(api_key=GOOGLE_API_KEY)
    # Generate content based on the prompt and the image
    response = client.models.generate_content(
        model=model,
        contents=[prompt, img]
    )    # Print the generated content
    print("\nGenerated content:")
    print(response.text)
else:
    print("Skipping image processing due to download or load error.")
# Out:
# Image downloaded successfully to phongnha.png
# Image loaded successfully.
#
# Generated content:
# This image captures a breathtaking, vast natural cavern, revealing a spectacular underground river system from an elevated perspective.
#
# From an aerial or high vantage point, the scene looks down into a colossal cave entrance, framed by dense, vibrant green foliage that spills over the top edges of the rock walls, suggesting a lush, tropical environment outside.
#
# The ceiling of the cave is dark and cavernous, with numerous intricate stalactites of varying lengths and shapes hanging down. Some are slender and pointed, while others are broader and more irregular, contributing to the cave's raw, ancient feel. The massive archway opens up to a brilliant burst of light in the distance, suggesting an exit or another large opening, through which a misty haze is visible, creating a dramatic and ethereal glow that reflects on the water below.
#
# Winding through the floor of this epic cavern is a serene river of striking emerald green or deep turquoise water. Its surface reflects the intense light from the distant opening, creating shimmering patches that contrast beautifully with the darker, shadowed sections of the river. The riverbanks are narrow and composed of earthy tones, with scattered patches of green grass and small plants.
#
# Along both banks of the winding river, towering rock formations rise like ancient pillars or gigantic stalagmites. These formations vary significantly in height and shape; some appear gnarled and textured with horizontal striations, resembling stacked boulders, while others are more conical or spire-like. Their earthy tones of brown, gray, and reddish-orange are occasionally softened by patches of green moss and small plants clinging to their surfaces, especially those closer to the light source.
#
# The overall impression is one of immense natural grandeur and timeless beauty, a mysterious and awe-inspiring landscape carved by water and time, hinting at hidden wonders within the earth.

# %% [markdown]
# ## Describe Another Image File

# %%
# Download a different image from a reliable source
image_url = "https://raw.githubusercontent.com/vuhung16au/MachineLearning-GenAI/refs/heads/main/Gemini/pytorch.png"
image_path = "pytorch.png"
try:
    # Download the image
    response = requests.get(image_url)
    response.raise_for_status()  # Raise an exception for bad status codes
    with open(image_path, 'wb') as f:
        f.write(response.content)
    print(f"Image downloaded successfully to {image_path}")
    # Load the image
    img = Image.open(image_path)
    print("Image loaded successfully.")
except requests.exceptions.RequestException as e:
    print(f"Error downloading image: {e}")
    img = None
except FileNotFoundError:
    print(f"Error: Image file not found at {image_path}")
    img = None
if img:
    # Define a prompt
    prompt = "Describe this image."
    # Select a Gemini model that supports multimodal input
    # Make sure to use a model that supports both text and image input.
    # The list of available models can be checked with `genai.list_models()`.
    # The configured model supports multimodal input.
    client = genai.Client(api_key=GOOGLE_API_KEY)
    # Generate content based on the prompt and the image
    response = client.models.generate_content(
        model=model,
        contents=[prompt, img]
    )    # Print the generated content
    print("\nGenerated content:")
    print(response.text)
else:
    print("Skipping image processing due to download or load error.")
# Out:
# Image downloaded successfully to pytorch.png
# Image loaded successfully.
#
# Generated content:
# This image is a striking digital illustration with a dark, tech-oriented theme, focused on Artificial Intelligence and Natural Language Processing.
#
# Here's a breakdown:
#
# 1.  **Central Element - The Brain:** A luminous, glowing blue-cyan outline of a human brain dominates the lower half of the image, positioned slightly to the right of the center. The brain is depicted in profile, showing its intricate folds (gyri and sulci). Internally, it is filled with an intricate network of interconnected glowing lines and nodes, resembling neural pathways or a complex digital circuit board. Scattered within this network are several pulsating red-orange points, suggesting areas of high activity or processing.
#
# 2.  **Background and Data:** The background is a deep, dark blue to black gradient, creating a sense of depth and focus on the glowing elements. Extending from and around the brain is a faint, ethereal network of glowing blue lines, similar to circuit traces or data pathways, further reinforcing the digital and interconnected theme. Scattered throughout the background, particularly in the upper and lower corners, are subtle, translucent overlays of alphanumeric characters, binary code, and abstract digital patterns, indicating data flow and computational processes.
#
# 3.  **Text Overlay:** In the upper left quadrant, prominent white text clearly states the image's subject:
#     *   "**Natural Language Processing (NLP)**" (in a large, bold sans-serif font)
#     *   "with PyTorch" (in a slightly smaller font below)
#     *   Next to "PyTorch" is the distinct PyTorch logo, a stylized blue-green geometric shape.
#
# 4.  **Overall Aesthetic:** The image has a futuristic and high-tech aesthetic, utilizing contrasting dark backgrounds with vibrant blue and red glows. The combination of the human brain with digital circuitry and data effectively conveys themes of artificial intelligence, machine learning, neural networks, and the intersection of biology and computing, specifically in the context of Natural Language Processing powered by PyTorch. A very subtle, dark grey star-like logo is visible in the bottom right corner.

# %% [markdown]
# ## Describe Image File Again

# %%
import tensorflow as tf
# Download an image using tf.keras.utils.get_file
image_url = "https://raw.githubusercontent.com/vuhung16au/MachineLearning-GenAI/refs/heads/main/Gemini/pytorch.png"
image_path = tf.keras.utils.get_file('pytorch.png', origin=image_url, cache_dir='.')
try:
    # Load the image
    img = Image.open(image_path)
    print(f"Image loaded successfully from {image_path}.")
except FileNotFoundError:
    print(f"Error: Image file not found at {image_path}")
    img = None
if img:
    # Define a prompt
    prompt = "Describe this image."
    # Select a Gemini model that supports multimodal input
    client = genai.Client(api_key=GOOGLE_API_KEY)
    # Generate content based on the prompt and the image
    response = client.models.generate_content(
        model=model,
        contents=[prompt, img]
    )    # Print the generated content
    print("\nGenerated content:")
    print(response.text)
else:
    print("Skipping image processing due to load error.")
# Out:
# Image loaded successfully from ./datasets/pytorch.png.
#
# Generated content:
# This image is a vibrant and futuristic digital artwork, primarily dark blue and black, with glowing accents.
#
# At the center of the lower half of the image is a highly stylized, luminous human brain, outlined in bright neon blue. Inside the brain, a dense network of glowing light blue lines forms intricate connections, resembling neural pathways or advanced circuitry. Numerous small, radiant dots, predominantly yellow-orange and some red, are scattered along these lines, suggesting active processing, data flow, or neural firing.
#
# The brain is set against a dark, deep blue-black background that is intricately patterned with glowing light blue circuit board-like lines and scattered digital elements, including faint binary code (0s and 1s) and abstract data points. These lines extend outward from the brain, creating a sense of a vast, interconnected digital network. A subtle, soft blue glow emanates from the edges of the image, enhancing the technological and immersive feel.
#
# Prominently displayed at the top of the image in bold white text are the words:
# **Natural Language Processing (NLP)**
# with PyTorch
# The text "PyTorch" is accompanied by its distinctive blue logo, featuring interconnected hexagonal shapes.
#
# The overall aesthetic conveys themes of artificial intelligence, computational thought, neural networks, and advanced data processing, specifically linking human intelligence (the brain) with cutting-edge technology and machine learning frameworks for language understanding.

# %% [markdown]
# # Audio File Processing Demo

# %% [markdown]
# ## Load Audio File

# %%
from google import genai
import time

# Define a prompt to describe the audio content
prompt = "Describe the content of this audio file. Include details about any music, speech, sounds, or other audio elements you can identify."

# !wget https://github.com/vuhung16au/MachineLearning-GenAI/raw/refs/heads/main/Gemini/enigma.mp3

audio_path = "enigma.mp3"

# Select a Gemini model that supports multimodal input (including audio)
client = genai.Client(api_key=GOOGLE_API_KEY)

try:
    # Upload the audio file to Gemini API
    audio_file = client.files.upload(file=audio_path)
    print(f"Uploaded file '{audio_file.display_name}' as: {audio_file.uri}")
    
    # Wait for the file to be processed
    # File processing handled automatically by google.genai
    print(f'Audio file processing complete. State: {audio_file.state}')
    
    # Check if the file processing was successful before generating content
    # Process the uploaded file directly with google.genai
    if audio_file.state == 'ACTIVE':    
        # Generate content based on the prompt and the uploaded audio file
        response = client.models.generate_content(
            model=model,
            contents=[prompt, audio_file]
        )
        
        # Print the generated content
        print("\nGenerated content:")
        print(response.text)
        
        # Clean up the uploaded file
        client.files.delete(audio_file.name)
        print(f"Deleted uploaded file: {audio_file.display_name}")
    else:
        print(f"Audio file processing failed with state: {audio_file.state}")
        
except Exception as e:
    print(f"Error processing audio: {e}")
# Out:
# Uploaded file 'None' as: https://generativelanguage.googleapis.com/v1beta/files/lkk08hbimgqz
# Audio file processing complete. State: ACTIVE
#
# Generated content:
# The audio file contains instrumental music, primarily featuring a piano.
#
# Here's a breakdown of the audio elements:
#
# *   **Music:** The dominant element is a slow, melodic, and gentle piano piece. The piano plays both the main melody and accompanying chords, creating a reflective and serene atmosphere.
# *   **Instrumentation:** In addition to the piano, there is a soft, sustained background pad sound, likely from synthesized strings or a synth pad. This adds a warm, ethereal, and atmospheric layer beneath the piano, enhancing the tranquil mood.
# *   **Tempo and Mood:** The music is played at a very slow tempo, contributing to a calm, peaceful, and somewhat melancholic or introspective mood. The dynamics remain relatively soft throughout, maintaining a consistently gentle presence.
# *   **Speech:** There is no speech or vocals present in the audio file.
# *   **Other Sounds:** No other identifiable sounds, such as environmental noises, foley, or percussive elements, are present.
#
# Overall, the audio file features a calming and reflective instrumental piece, driven by piano and supported by an atmospheric pad.
# Error processing audio: delete() takes 1 positional argument but 2 were given

# %% [markdown]
# ## Audio File Processing Demo

# %%
from google.genai import types
import google.genai as genai

# Configure the client with API key
client = genai.Client(api_key=GOOGLE_API_KEY)

try:
    # Read the audio file as bytes
    with open(audio_path, 'rb') as f:
        audio_bytes = f.read()
    
    print(f"Successfully loaded audio file: {audio_path}")
    print(f"Audio file size: {len(audio_bytes)} bytes")
    
    # Generate content using the google.genai library
    response = client.models.generate_content(
        model=model,
        contents=[
            'Describe this audio clip. Include details about any music, speech, sounds, or other audio elements you can identify.',
            types.Part.from_bytes(
                data=audio_bytes,
                mime_type='audio/mp3',
            )
        ]
    )
    
    print("\nGenerated content:")
    print(response.text)
    
except FileNotFoundError:
    print(f"Error: Audio file not found at {audio_path}")
    print("Make sure the audio file was downloaded successfully in the previous steps.")
except Exception as e:
    print(f"Error processing audio with google.genai: {e}")
# Out:
# Successfully loaded audio file: enigma.mp3
# Audio file size: 2468905 bytes
#
# Generated content:
# This audio clip features **instrumental music**, primarily characterized by a **delicate piano melody**. The overall mood is **calm, peaceful, and somewhat melancholic or reflective**.
#
# Here's a breakdown of the audio elements:
#
# *   **Music (0:00-1:54):**
#     *   The piece begins with a **solo piano**, playing a **slow, sparse, and gentle melody**. The notes are mostly in the middle to higher register, creating an introspective and slightly wistful atmosphere.
#     *   Around the **0:26 mark**, **soft, sustained string instruments** gradually enter. They provide a warm, harmonic background, adding depth and fullness to the sound without overpowering the piano. The strings sound like a pad or a small ensemble, offering sustained chords rather than a distinct melodic line.
#     *   The piano continues to carry the main melodic line, which gradually becomes a bit more developed and slightly richer in accompaniment as the track progresses, particularly between **0:50 and 1:20**. The strings swell gently at times, creating a subtle dynamic arc.
#     *   Around **1:25**, the string elements begin to fade, leaving the **piano once again as the primary instrument**. The melody becomes more sparse and delicate, echoing the opening section.
#     *   The music slowly fades out with the piano, concluding on a tranquil note around **1:50**.
#     *   The tempo is consistently very slow, contributing to the calming effect. The harmony suggests a minor key, which lends to the contemplative and slightly melancholic feel.
#
# *   **Speech:** There is **no speech** present in the audio clip.
# *   **Sounds/Other Audio Elements:** There are **no discernible sound effects** or other audio elements beyond the music itself.
#
# The music could be classified as **ambient classical, New Age, or contemporary instrumental**, suitable for relaxation, meditation, or as background music.

# %% [markdown]
# # Document (PDF) Processing Demo

# %% [markdown]
# ## Load PDF File

# %%
import tensorflow as tf
# Download a sample PDF file
pdf_url = "https://arxiv.org/pdf/1706.03762.pdf"
pdf_path = tf.keras.utils.get_file('attention_is_all_you_need.pdf', origin=pdf_url, cache_dir='.')
print(f"PDF downloaded successfully to {pdf_path}")
# Out:
# PDF downloaded successfully to ./datasets/attention_is_all_you_need.pdf

# %% [markdown]
# ## Process PDF File

# %%
import pypdf
# Load the downloaded PDF file
try:
    reader = pypdf.PdfReader(pdf_path)
    # Extract text from the first few pages as an example
    pdf_text = ""
    for page_num in range(min(3, len(reader.pages))): # Process first 3 pages
        pdf_text += reader.pages[page_num].extract_text()
    print("PDF loaded and text extracted from the first few pages.")
except Exception as e:
    print(f"Error loading or processing PDF: {e}")
    pdf_text = None
if pdf_text:
    # Define a prompt
    prompt = "Summarize the key contributions of this research paper based on the provided text."
    # Select a Gemini model that supports multimodal input (text and PDF)
    # The configured model supports text and potentially understands the extracted text content.
    client = genai.Client(api_key=GOOGLE_API_KEY)
    # Use the selected model to generate content based on the prompt and the loaded PDF text
    # The API takes content as a list of parts.
    contents = [prompt, pdf_text]
    response = client.models.generate_content(
        model=model,
        contents=contents
    )    # Print the generated content
    print("\nGenerated content:")
    print(response.text)
else:
    print("Skipping PDF processing due to load or processing error.")
# Out:
# PDF loaded and text extracted from the first few pages.
#
# Generated content:
# The research paper "Attention Is All You Need" introduces the **Transformer**, a novel and simplified neural network architecture for sequence transduction. Its key contributions are:
#
# 1.  **Sole Reliance on Attention Mechanisms:** The Transformer dispenses entirely with traditional recurrent (RNNs) and convolutional neural networks (CNNs), relying *solely* on attention mechanisms (specifically multi-head self-attention) to draw global dependencies between input and output. This is a significant departure from dominant models of the time.
#
# 2.  **Superior Performance and Efficiency:**
#     *   It achieves **state-of-the-art quality** on machine translation tasks, setting new BLEU scores (e.g., 28.4 BLEU on WMT 2014 English-to-German, improving over existing bests by over 2 BLEU; 41.8 BLEU on WMT 2014 English-to-French).
#     *   It is **more parallelizable** and requires **significantly less training time and cost** (e.g., training for 3.5 days on eight GPUs for the En-Fr task, a small fraction of prior bests).
#
# 3.  **Generalizability:** The Transformer demonstrates its versatility by successfully applying to other tasks, such as English constituency parsing, indicating its broad applicability beyond machine translation.
#
# In essence, the paper proposes a more parallelizable, faster-to-train, and higher-quality sequence transduction model by completely abandoning recurrence and convolutions in favor of an architecture built exclusively on attention.

# %% [markdown]
# # Video Processing Demo

# %% [markdown]
# ## Load Video File

# %%
import tensorflow as tf
# Download a sample MP4 video file
video_url = "https://github.com/vuhung16au/MachineLearning-GenAI/raw/refs/heads/main/Gemini/halong.mp4"
video_path = tf.keras.utils.get_file('halong.mp4', origin=video_url, cache_dir='.')
print(f"Video downloaded successfully to {video_path}")
# Out:
# Video downloaded successfully to ./datasets/halong.mp4

# %% [markdown]
# ## Describe Video

# %%
import subprocess
import os
from PIL import Image
import numpy as np
from google import genai
import time
# Load the downloaded video file path (assuming video_path is already defined from previous steps)
# video_path = "./datasets/halong.mp4" # Uncomment and replace if video_path is not defined
# Create a directory to store extracted frames
frames_dir = "./video_frames"
os.makedirs(frames_dir, exist_ok=True)
# Define the command to extract frames using ffmpeg
# This command extracts one frame every 5 seconds
ffmpeg_command = [
    "ffmpeg",
    "-i", video_path,
    "-vf", "fps=1/5",
    f"{frames_dir}/frame_%04d.png"
]
try:
    # Execute the ffmpeg command
    print(f"Executing ffmpeg command: {' '.join(ffmpeg_command)}")
    subprocess.run(ffmpeg_command, check=True, capture_output=True, text=True)
    print("Frame extraction completed successfully.")
    # Load the extracted frames
    frames = []
    frame_files = sorted([f for f in os.listdir(frames_dir) if f.startswith('frame_') and f.endswith('.png')])
    for frame_file in frame_files:
        img_path = os.path.join(frames_dir, frame_file)
        frames.append(Image.open(img_path))
    print(f"Loaded {len(frames)} frames.")
except FileNotFoundError:
    print("Error: ffmpeg command not found. Please ensure ffmpeg is installed and in your PATH.")
    frames = []
except subprocess.CalledProcessError as e:
    print(f"Error during ffmpeg execution: {e}")
    print(f"stdout: {e.stdout}")
    print(f"stderr: {e.stderr}")
    frames = []
except Exception as e:
    print(f"Error loading extracted frames: {e}")
    frames = []
if frames:
    # Define a prompt related to the video content
    prompt = "Describe the key actions and characters in this video based on the provided frames."
    # Select a Gemini model that supports multimodal input (text and image)
    client = genai.Client(api_key=GOOGLE_API_KEY)
    # Use the selected model to generate content based on the prompt and the extracted frames
    # The API takes content as a list of parts.
    contents = [prompt] + frames
    response = client.models.generate_content(
        model=model,
        contents=contents
    )# Print the generated content
    print("\nGenerated content:")
    print(response.text)
else:
    print("Skipping video processing due to frame extraction or loading error.")
# Out:
# Executing ffmpeg command: ffmpeg -i ./datasets/halong.mp4 -vf fps=1/5 ./video_frames/frame_%04d.png
# Frame extraction completed successfully.
# Loaded 2 frames.
#
# Generated content:
# Based on the provided frames, which are identical and static:
#
# **Key Actions:**
# There are no discernible actions taking place within these frames. The scene is entirely static, depicting a landscape rather than an event in progress. No movement, human activity, or natural processes (like waves crashing, birds flying, etc.) are depicted.
#
# **Key Characters:**
# There are no human or animal characters visible in these frames. The primary "characters" of the scene are the natural geographical features:
# *   **Numerous Karstic Islands/Mountains:** These are the dominant features, large, steep, and heavily forested, rising dramatically from the water. They are the main subjects of the visual.
# *   **The Body of Water:** A vast expanse of emerald or jade-green water that surrounds the islands, reflecting the bright sky.
# *   **Sunlight:** Playing a significant role in illuminating the scene and creating reflections on the water.
#
# In summary, the frames capture a breathtaking, static panorama of a natural landscape, likely an archipelago or bay, emphasizing its serene beauty and geological formations, without any discernible actions or living characters.

# %% [markdown]
# # References

# %% [markdown]
# - https://cloud.google.com/vertex-ai/generative-ai/docs/models/gemini/2-5-flash
# - https://storage.googleapis.com/model-cards/documents/gemini-2.5-flash.pdf
# - https://pypi.org/project/google-genai/
